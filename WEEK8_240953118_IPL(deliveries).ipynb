# %%
# Data Visualization
# BTech Computer Science Stream , January 2025
# Week 8 Data Aggregation and Group Operations Exercise - Demonstration Code
# Name: Divyansh Garg , reg number - 240953118 , Date: 10/03/2025

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("deliveries.csv")
df
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
# 1. Find and visualize the total runs scored by each team.
runs = df.groupby('batting_team')['total_runs'].sum().reset_index()
runs = runs.sort_values(by='total_runs', ascending=False)
runs
# Out:
#                    batting_team  total_runs
# 10               Mumbai Indians       42176
# 8         Kolkata Knight Riders       39331
# 0           Chennai Super Kings       38629
# 16  Royal Challengers Bangalore       37692
# 13             Rajasthan Royals       34747
# 6               Kings XI Punjab       30064
# 18          Sunrisers Hyderabad       29071
# 3              Delhi Daredevils       24296
# 2                Delhi Capitals       14900
# 1               Deccan Chargers       11463
# 12                 Punjab Kings        9536
# 5                Gujarat Titans        7757
# 9          Lucknow Super Giants        7510
# 11                Pune Warriors        6358
# 4                 Gujarat Lions        4862
# 17  Royal Challengers Bengaluru        2930
# 14       Rising Pune Supergiant        2470
# 15      Rising Pune Supergiants        2063
# 7          Kochi Tuskers Kerala        1901

# %%
# plot for Q1 ( doing a bar graph :) )
plt.figure(figsize=(6,4))
sns.barplot(x='total_runs', y='batting_team', data=runs, palette='viridis')
plt.xlabel("Total Runs Scored")
plt.ylabel("Team")
plt.title("Total Runs Scored by Each Team")
plt.show()
# Out:
# C:\Users\HIMYN\AppData\Local\Temp\ipykernel_18872\2668326694.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='total_runs', y='batting_team', data=runs, palette='viridis')

# %% [markdown]
# Observation:
# 1) Most runs are made by Mumbai Indians
# 2) Kochi Tusker Kerala made the least over the season

# %%
# 2. Identify and display the names of the top 10 highest-scoring batters with their total runs scored
topb = df.groupby('batter')['batsman_runs'].sum().reset_index()
topb = topb.sort_values(by='batsman_runs', ascending=False).head(10)
topb
# Out:
#              batter  batsman_runs
# 631         V Kohli          8014
# 512        S Dhawan          6769
# 477       RG Sharma          6630
# 147       DA Warner          6567
# 546        SK Raina          5536
# 374        MS Dhoni          5243
# 30   AB de Villiers          5181
# 124        CH Gayle          4997
# 501      RV Uthappa          4954
# 282      KD Karthik          4843

# %% [markdown]
# Observation :
# 1) Top batter is Virat Kohli
# 2) KD karthik is at the bottom this season

# %%
# 3. Find and visualize the top 10 bowlers with the most wickets
top_bowlers = df[df['dismissal_kind'].notna()]
top_bowlers = top_bowlers.groupby('bowler')['dismissal_kind'].count().reset_index()
top_bowlers = top_bowlers.sort_values(by='dismissal_kind', ascending=False).head(10)
plt.figure(figsize=(6,4))
sns.barplot(x='dismissal_kind', y='bowler', data=top_bowlers, palette='magma')
plt.xlabel("Total Wickets Taken")
plt.ylabel("Bowler")
plt.title("Top 10 Bowlers with Most Wickets")
plt.show()
# Out:
# C:\Users\HIMYN\AppData\Local\Temp\ipykernel_18872\798592437.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='dismissal_kind', y='bowler', data=top_bowlers, palette='magma')

# %% [markdown]
# Observation :
# 1) Top bowler who took the max wickets this season is YS Chahal
# 2) RA Jadeja took around only 175 wickets

# %%
# 4. Tabulate and visualize the total number of extras conceded by each team.
extras = df.groupby('bowling_team')['extra_runs'].sum().reset_index()
extras
# Out:
#                    bowling_team  extra_runs
# 0           Chennai Super Kings        1842
# 1               Deccan Chargers         659
# 2                Delhi Capitals         725
# 3              Delhi Daredevils        1268
# 4                 Gujarat Lions         188
# 5                Gujarat Titans         295
# 6               Kings XI Punjab        1571
# 7          Kochi Tuskers Kerala         110
# 8         Kolkata Knight Riders        1957
# 9          Lucknow Super Giants         386
# 10               Mumbai Indians        2295
# 11                Pune Warriors         335
# 12                 Punjab Kings         480
# 13             Rajasthan Royals        1917
# 14       Rising Pune Supergiant         111
# 15      Rising Pune Supergiants         108
# 16  Royal Challengers Bangalore        2040
# 17  Royal Challengers Bengaluru         151
# 18          Sunrisers Hyderabad        1254

# %% [markdown]
# Observation :
# 1) Mumbai Indians made the most extra runs
# 2) Rising Pune Supergiants made the least extra runs

# %%
# 5. Tabulate and visualize the batsmen (top 5) involved in the most run-outs.
run_outs = df[df['dismissal_kind'] == 'run out'].groupby('batter')['dismissal_kind'].count().reset_index()
run_outs = run_outs.sort_values(by='dismissal_kind', ascending=False).head(5)
run_outs
# Out:
#          batter  dismissal_kind
# 186    MS Dhoni              25
# 247   RG Sharma              20
# 136  KD Karthik              20
# 329     V Kohli              20
# 266    S Dhawan              16

# %%
# plot for Q5
plt.figure(figsize=(6,4))
sns.barplot(x='dismissal_kind', y='batter', data=run_outs, palette='rocket')
plt.xlabel("Run-Outs")
plt.ylabel("Batter")
plt.title("Top 5 Batsmen Involved in Most Run-Outs")
plt.show()
# Out:
# C:\Users\HIMYN\AppData\Local\Temp\ipykernel_18872\2839031647.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='dismissal_kind', y='batter', data=run_outs, palette='rocket')

# %% [markdown]
# Observation:
# 1) MS Dhoni made the most run outs :)

# %%
# Question 6: Top 5 bowlers who conceded the most extras
extras_b = df.groupby('bowler')['extra_runs'].sum().reset_index()
extras_b = extras_b.sort_values(by='extra_runs', ascending=False).head(5)
extras_b
# Out:
#          bowler  extra_runs
# 71      B Kumar         307
# 438  SL Malinga         292
# 119    DJ Bravo         258
# 494    UT Yadav         257
# 355    R Ashwin         257

# %% [markdown]
# Observation:
# 1) B Kumar made the most extra runs

# %%
# Question 7: Most common dismissal type
dismissal_counts = df['dismissal_kind'].value_counts().reset_index()
dismissal_counts.columns = ['Dismissal Type', 'Count']
dismissal_counts
# Out:
#           Dismissal Type  Count
# 0                 caught   8063
# 1                 bowled   2212
# 2                run out   1114
# 3                    lbw    800
# 4      caught and bowled    367
# 5                stumped    358
# 6           retired hurt     15
# 7             hit wicket     15
# 8  obstructing the field      3
# 9            retired out      3

# %% [markdown]
# Observation :
# 1) Max dismissal count type is "caught"
# 2) Least dismissal count type is "retired out"

# %%
# Question 8: Top 3 overs with the highest run rate
over_runs = df.groupby('over')['total_runs'].sum()
over_balls = df.groupby('over')['ball'].count()
over_run_rate = (over_runs / over_balls).reset_index()
over_run_rate.columns = ['Over', 'Run Rate']
top_overs = over_run_rate.sort_values(by='Run Rate', ascending=False).head(3)
print("Top 3 Overs with Highest Run Rate:\n")
top_overs
# Out:
# Top 3 Overs with Highest Run Rate:
#     Over  Run Rate
# 19    19  1.776855
# 18    18  1.646896
# 17    17  1.587839

# %% [markdown]
# Observation :
# 1) 19 was the top over with the run rate of 1.77

# %%
# Question 9: Powerplay performance (first 6 overs)
powerplay= df[df['over'] < 6].groupby('batting_team')['total_runs'].sum().reset_index()
powerplay = powerplay.sort_values(by='total_runs', ascending=False)
powerplay
# Out:
#                    batting_team  total_runs
# 10               Mumbai Indians       12225
# 8         Kolkata Knight Riders       11941
# 0           Chennai Super Kings       10991
# 16  Royal Challengers Bangalore       10919
# 13             Rajasthan Royals       10226
# 6               Kings XI Punjab        8954
# 18          Sunrisers Hyderabad        8937
# 3              Delhi Daredevils        7360
# 2                Delhi Capitals        4709
# 1               Deccan Chargers        3417
# 12                 Punjab Kings        2841
# 5                Gujarat Titans        2184
# 9          Lucknow Super Giants        2080
# 11                Pune Warriors        1895
# 4                 Gujarat Lions        1559
# 17  Royal Challengers Bengaluru         876
# 14       Rising Pune Supergiant         785
# 7          Kochi Tuskers Kerala         680
# 15      Rising Pune Supergiants         638

# %% [markdown]
# Observation :
# 1) Best powerplay was showed by Mumbai Indians
# 2) Rising Pune Supergiants need to step up :)

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='total_runs', y='batting_team', data=powerplay_runs, palette='coolwarm')
plt.xlabel("Total Runs in Powerplay")
plt.ylabel("Team")
plt.title("Powerplay Performance (First 6 Overs)")
plt.show()
# Out:
# C:\Users\HIMYN\AppData\Local\Temp\ipykernel_18872\3501712944.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='total_runs', y='batting_team', data=powerplay_runs, palette='coolwarm')

# %%
# Question 10: Top 5 batsmen with the most sixes and fours
sixes = df[df['batsman_runs'] == 6].groupby('batter')['batsman_runs'].count().reset_index()
fours = df[df['batsman_runs'] == 4].groupby('batter')['batsman_runs'].count().reset_index()
sixes.columns = ['Batter', 'Sixes']
fours.columns = ['Batter', 'Fours']
boundaries = pd.merge(sixes, fours, on='Batter', how='outer').fillna(0)
boundaries['Total Boundaries'] = boundaries['Sixes'] + boundaries['Fours']
top_boundaries = boundaries.sort_values(by='Total Boundaries', ascending=False).head(10)
top_boundaries
# Out:
#              Batter  Sixes  Fours  Total Boundaries
# 532         V Kohli  273.0  708.0             981.0
# 437        S Dhawan  153.0  768.0             921.0
# 126       DA Warner  236.0  663.0             899.0
# 409       RG Sharma  281.0  599.0             880.0
# 109        CH Gayle  359.0  408.0             767.0
# 462        SK Raina  204.0  506.0             710.0
# 25   AB de Villiers  253.0  414.0             667.0
# 427      RV Uthappa  182.0  481.0             663.0
# 243      KD Karthik  161.0  466.0             627.0
# 323        MS Dhoni  252.0  363.0             615.0

# %% [markdown]
# Observation :
# 1) Virat Kohli with the most boundaries once again

# %%
plt.figure(figsize=(12, 6))
top_boundaries.plot(x='Batter', kind='bar', stacked=True, figsize=(10, 6), colormap='coolwarm')
plt.xlabel("Batter")
plt.ylabel("Total Boundaries")
plt.title("Top 5 Batsmen with Most Sixes and Fours")
plt.legend(["Sixes", "Fours"])
plt.show()
