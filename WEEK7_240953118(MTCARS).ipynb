# %%
# Data Visualization
# BTech Computer Science Stream , January 2025
# Week 7  Plotting and Visualization using Matplotlib & Seaborn Exercise  - Demonstration Code
# Name: Divyansh Garg , reg number - 240953118 , Date: 24/02/2025

# %%
#import the libraries such as numpy, pandas, matplotlib and seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Upload the dataset
df=pd.read_csv('mtcars.csv')
pd.set_option('display.max_columns', 100)  #display all columns
pd.set_option('display.max_rows',None)      #display all rows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 #Upload the dataset
# ----> 2 df=pd.read_csv('mtcars.csv')
#       3 pd.set_option('display.max_columns', 100)  #display all columns
#       4 pd.set_option('display.max_rows',None)      #display all rows
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mtcars.csv'

# %%
#View the dataset
df

# %%
# 1. Extract the 'mpg' column from the dataframe & Plot the mpg values as a line plot
mpg = df['mpg']
mpg.plot()
# The default plot will be a line plot where the x-axis represents the index of the data points
# and the y-axis represents the 'mpg' values.
# Out:
# <AxesSubplot:>

# %%
# 2. Select only the 'cyl', 'wt', and 'mpg' columns from the dataframe & Plot the selected dataframe columns
df = df[['cyl', 'wt', 'mpg']]
df.plot()

# By default, Pandas will create a line plot for all numerical columns ('cyl', 'wt', 'mpg')
# - The x-axis represents the index of the dataframe.
# - The y-axis represents the values of 'cyl', 'wt', and 'mpg'.
# - Each column gets a separate line in the plot.
# Out:
# <AxesSubplot:>

# %%
#3. Bar Plot- the count of cars by the number of cylinders
cyl_counts = df['cyl'].value_counts()
cyl_counts.plot(kind='bar', color='green')
plt.title('Count of Cars by Cylinders')
plt.xlabel('Cylinders')
plt.ylabel('Count')
plt.show()

# %%
#use ggplot for better visualization. ggplot2 is based on the Grammar of Graphics, which provides a structured approach to building plots.
# This makes it easy to add, remove, or modify components (e.g., layers, scales, themes) without breaking the code.
plt.style.use('ggplot')

# %%
#4. Scatter plot of weight vs mpg
df.plot(
    kind="scatter",
    x="wt",
    y="mpg",
    figsize=(9,9),
    color="black",
);

# %%
#5. Box plot of MPG for each cylinder category
plt.figure(figsize=(8, 6))
sns.boxplot(x='cyl', y='mpg', data=df)
plt.title('MPG by Cylinder Category')
plt.xlabel('Number of Cylinders')
plt.ylabel('MPG')
plt.show()

# %%
# 6. Histogram of MPG for all cars

x = df['mpg']

# Plotting the histogram
plt.hist(x)

# Adding title to the plot
plt.title("Distribution of MPG in Cars Dataset")

# Adding label on the y-axis (Frequency of each cylinder count)
plt.ylabel('Frequency')

# Adding label on the x-axis (Number of cylinders in cars)
plt.xlabel('MPG')

# Displaying the plot
plt.show()

# %%
# 7. This pie chart shows the proportion of cars with 4, 6, or 8 cylinders.
# Group data by 'cyl' and calculate counts
cyl_counts = df['cyl'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    cyl_counts,
    labels=cyl_counts.index,
    autopct='%1.1f%%',  # Add percentage labels
    colors=['skyblue', 'lightgreen', 'orange'],
    startangle=140,  # Start angle of the pie chart
    explode=[0.1, 0, 0]  # Emphasize the first slice (4 cylinders)
)
plt.title('Proportion of Cars by Number of Cylinders')
plt.show()

# %%
#8. Pie Chart for Transmission Types

# Reload the original dataframe to include the 'am' column
df = pd.read_csv('mtcars.csv')

am_counts = df['am'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    am_counts,
    labels=['Automatic', 'Manual'],  # Custom labels
    autopct='%1.1f%%',
    colors=['gold', 'lightcoral'],
    startangle=90
)
plt.title('Proportion of Cars by Transmission Type')
plt.show()

# %%
# 9. Nested Pie Chart which needs Data preparation
outer_counts = df['cyl'].value_counts()
inner_counts = df['gear'].value_counts()

# Extract labels and sizes
outer_labels = outer_counts.index.astype(str)
outer_sizes = outer_counts.values

inner_labels = inner_counts.index.astype(str)
inner_sizes = inner_counts.values

# Create nested pie chart
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(outer_sizes, labels=outer_labels, radius=1, autopct='%1.1f%%', 
       colors=['skyblue', 'lightgreen', 'orange'], wedgeprops=dict(width=0.3, edgecolor='w'))

ax.pie(inner_sizes, labels=inner_labels, radius=0.7, autopct='%1.1f%%', 
       colors=['pink', 'purple', 'cyan'], wedgeprops=dict(width=0.3, edgecolor='w'))

ax.set(aspect="equal")
plt.title('Nested Pie Chart: Cylinders (Outer) and Gears (Inner)')
plt.show()
